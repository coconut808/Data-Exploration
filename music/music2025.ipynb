# %% [markdown]
# Source: [https://www.kaggle.com/datasets/ayeshaimran123/top-youtube-music-hits-2025](https://www.kaggle.com/datasets/ayeshaimran123/top-youtube-music-hits-2025)
#
# Just exploring the dataframe as I learn

# %%
import pandas as pd
import numpy as np

# %%
music = pd.read_csv('~/datasets/youtube-top-100-songs-2025.csv')
music.head()
# Out:
#                                                title  \
# 0   ROSÉ & Bruno Mars - APT. (Official Music Video)
# 1  Lady Gaga, Bruno Mars - Die With A Smile (Offi...
# 2  Reneé Rapp - Leave Me Alone (Official Music Vi...
# 3  Billie Eilish - BIRDS OF A FEATHER (Official M...
# 4            Reneé Rapp - Mad (Official Music Video)
#
#                                            fulltitle  \
# 0   ROSÉ & Bruno Mars - APT. (Official Music Video)
# 1  Lady Gaga, Bruno Mars - Die With A Smile (Offi...
# 2  Reneé Rapp - Leave Me Alone (Official Music Vi...
# 3  Billie Eilish - BIRDS OF A FEATHER (Official M...
# 4            Reneé Rapp - Mad (Official Music Video)
#
#                                          description  view_count categories  \
# 0  ROSÉ & Bruno Mars - APT.\nDownload/stream: ht...  2009014557      Music
# 1  MAYHEM OUT NOW\nhttp://ladygaga.com \n \nListe...  1324833300      Music
# 2  Listen to “BITE ME”, the new album from Reneé ...     2536628      Music
# ...

# %%
print(music.info())
music.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   title                   100 non-null    object
#  1   fulltitle               100 non-null    object
#  2   description             100 non-null    object
#  3   view_count              100 non-null    int64
#  4   categories              100 non-null    object
#  5   tags                    85 non-null     object
#  6   duration                100 non-null    int64
#  7   duration_string         100 non-null    object
#  8   live_status             100 non-null    bool
#  9   thumbnail               100 non-null    object
#  10  channel                 100 non-null    object
#  11  channel_url             100 non-null    object
#  12  channel_follower_count  100 non-null    int64
# dtypes: bool(1), int64(3), object(9)
# memory usage: 9.6+ KB
# None
# ...

# %%
music[["title","view_count","channel","channel_follower_count"]].sort_values(by="view_count", ascending=False)
# Out:
#                                                 title  view_count  \
# 0    ROSÉ & Bruno Mars - APT. (Official Music Video)  2009014557
# 1   Lady Gaga, Bruno Mars - Die With A Smile (Offi...  1324833300
# 3   Billie Eilish - BIRDS OF A FEATHER (Official M...   558329099
# 5                        Sabrina Carpenter - Espresso   472570966
# 14                       Kendrick Lamar - Not Like Us   397228595
# ..                                                ...         ...
# 21    JWAVY - SUNSET (FEAT. MARIBASED1) [MUSIC VIDEO]        7805
# 31                 NIGHT SKIES (Official Music Video)        6605
# 78  Insãne Shinobi & Johnnie Noct - REVENGE (Offic...        6174
# 65  Nelly Wap "Up Next" (Off The Porch Live Perfor...        4637
# 85  Ryan Collins - Stars n Stripes (Official Music...        1161
#
#                           channel  channel_follower_count
# 0                            ROSÉ                19200000
# ...

# %%
music.axes
# Out:
# [RangeIndex(start=0, stop=100, step=1),
#  Index(['title', 'fulltitle', 'description', 'view_count', 'categories', 'tags',
#         'duration', 'duration_string', 'live_status', 'thumbnail', 'channel',
#         'channel_url', 'channel_follower_count'],
#        dtype='object')]

# %%
# 0 is the index
music.axes[0]
# Out:
# RangeIndex(start=0, stop=100, step=1)

# %%
# 1 is the columns
music.axes[1]
# Out:
# Index(['title', 'fulltitle', 'description', 'view_count', 'categories', 'tags',
#        'duration', 'duration_string', 'live_status', 'thumbnail', 'channel',
#        'channel_url', 'channel_follower_count'],
#       dtype='object')

# %%
music.axes[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 music.axes[0]
#
# NameError: name 'music' is not defined
